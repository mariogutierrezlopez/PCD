# %% [markdown]
# ## Se solicita realizar ataques simultaneos a los siguientes sitios web:

# %%
import threading, os, platform, requests, json

# %% [markdown]
# # Hands on 04

# %% [markdown]
# <!-- PROFILE LINK -->
#
# <h1 style = "text-align:center; font-size: 30px">PROGRAMACIÓN CONCURRENTE Y DISTRIBUIDA</h1>
# <a href ="https://github.com/mariogutierrezlopez">
# <img src="https://avatars.githubusercontent.com/u/102418143?v=4" style="float:left;vertical-align:centre" width="110" height="110" title = "Mario Gutiérrez López 22102041">
# <a href ="https://github.com/mariogutierrezlopez?tab=repositories">
# <img src="https://media-exp1.licdn.com/dms/image/C4D0BAQEu_Aa76fcmPw/company-logo_200_200/0/1630998679429?e=2159024400&v=beta&t=2feC9GG7RWCWizTqsK5HzDWB1TL2DOQuAVwnMf6FFvk" title = "M21" alt="UE" width="110" height="110" style="float:right;vertical-align:centre">

# %%
numero_de_veces_hasta_matar_uem = 100000

# %%
url_ = "https://github.com/mariogutierrezlopez"

# %% [markdown]
# ## Http codigos

# %% [markdown]
# <img style="height: 400px" src="https://www.xeonbd.com/wp-content/uploads/HTTP-Response-Status-Codes.png"/>

# %%
from IPython import display as dp

# %%
dp.Image("HttpStatusCodes.png")

# %%
def matar_uem():
    print(requests.get(url_))
    threading.current_thread()

# %%
threading
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 requests.get(url_)
#
# NameError: name 'requests' is not defined

# %%
for i in range(numero_de_veces_hasta_matar_uem):
    threading.Thread(target=matar_uem()).start()

# %%
res_=requests.get("http://rpubs.com/christian_sucuzhanay")

# %%
res_.headers
# Out:
# {'Date': 'Thu, 06 Oct 2022 16:17:49 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Status': '200 OK', 'Cache-Control': 'max-age=0, private, must-revalidate', 'Referrer-Policy': 'strict-origin-when-cross-origin', 'X-Permitted-Cross-Domain-Policies': 'none', 'X-XSS-Protection': '1; mode=block', 'X-Request-Id': '0b3064a6-79ac-4763-b804-b6e5531d0222', 'X-Download-Options': 'noopen', 'ETag': 'W/"72f9be6d50e1e27d55ab028ba7a97fc7"', 'X-Frame-Options': 'SAMEORIGIN', 'X-Runtime': '0.031418', 'X-Content-Type-Options': 'nosniff', 'Set-Cookie': '_session_id=f196b05a7cfc3f6b39a526dcb33ea06e; path=/; HttpOnly', 'X-Powered-By': 'Phusion Passenger 6.0.2', 'Server': 'nginx/1.14.0 + Phusion Passenger 6.0.2', 'Content-Encoding': 'gzip'}

# %%
array = [] # Intento del ejercicio que ha mandado en clase (funcion que descarga cosas de manera concurrente)

# %%
def descarga(array):
    for i in range(len(array)-1):
        threading.Thread(target=matar_uem()).start()
